# %% [markdown]
# # EfficientNet-B0 Scratch

# %%
import numpy as np

# %% [markdown]
# # EfficientNet-B0
#
# Power of EfficientNet: **Compound Scaling**
#
# $$\text{depth}: d = \alpha^{\phi} \quad \text{width}: w = \beta^{\phi} \quad \text{resolution}: r = \gamma^{\phi}$$
#
# subjects to:
# $$\alpha \cdot \beta^{2} \cdot \gamma^{2} \approx 2$$
#
# With:
# - $\phi$ = scaling coefficient, for B0 ($\phi=1$)
# - $\alpha, \beta, \gamma$ = constants found via grid search
#
# ### MBConv (core building block)
# 1. Expansion (1x1 conv)
# $$x_{exp} = \sigma(W_{exp} \times x)$$
# 2. Depthwise Convolution
# $$x_{dw} = \sigma(W_{dw} \odot x_{exp})$$
# 3. Squeeze-and-Excitation (SE)
# $$s = \sigma(W_{2} \cdot \delta(W_{1} \cdot GAP(x_{dw})))$$
# 4. Projection (1x1 conv)
# $$x_{out} = W_proj \times x_{se}$$
#
# Additional Information:
# - $\sigma$: sigmoid activation function
# $$\sigma(x) = \frac{1}{1 + e^{-x}}$$
# - $\delta$: ReLU activation
# $$\delta(x) = \max(0, x)$$
# - $\text{Swish / SiLU}$: Swish activation function
# $$\text{SiLU}(x) = x\cdot \sigma(x)$$
# - GAP: Global Average Pooling
# $$GAP(x_{c}) = \frac{1}{H \cdot W} \sum_{i=1}^{H} \sum_{j=1}^{W} x_{c}(i, j)$$

# %%
# Activation Function
def linear(x: float) -> float:
    """compute linear activation function"""
    return x

def sigmoid(x: float) -> float:
    """compute sigmoid activation function"""
    return 1 / (1 + (np.exp(-x)))

def relu(x: float) -> float:
    """compute relu activation function"""
    return np.maximum(0, x)

def swish(x: float) -> float:
    """compute swish/silu activation function"""     
    return x * sigmoid(x)

# %%
# Global Average Pooling for EfficientNet
def global_average_pooling(x: np.ndarray) -> float:
    """global average pooling layer"""
    return np.mean(x, axis=(1, 2))

# %%
# Compound Scaling for EfficientNet
def compound_scaling(phi: int, alpha: float, beta: float, gamma: float) -> tuple:
    """
    Compound scaling method for EfficientNet that makes a balance between depth, width, and resolution of the network.

    Args:
        phi (int): scaling coefficient
        alpha (float): depth of the input
        beta (float): width of the input
        gamma (float): resolution of the input

    Returns:
        tuple: _description_
    """
    depth = alpha ** phi
    width = beta ** phi
    resolution = gamma ** phi
    
    return depth, width, resolution

# %%
# Stem Conv

# Standard Conv
def conv2d(x, weight, bias=None, stride=1, padding=0):
    """Perform a 2D convolution operation on the input tensor x using the provided weight and bias."""
    c_out, c_in, kh, kw = weight.shape
    c_in_x, h, w = x.shape
    
    assert c_in == c_in_x
    
    # Padding
    x_padded = np.pad(x, ((0, 0), (padding, padding), (padding, padding)))
    
    
    

def batch_normalization(x, gamma, beta, eps=1e-5):
    """Perform batch normalization on the input tensor x."""
    pass

def stem_conv(x, weight, bias, gamma, beta):
    x = conv2d(x, weight, bias, stride=2, padding=1)
    x = batch_normalization(x, gamma, beta)
    x = swish(x)
    return x

# %%
# MBConv Block

# Expansion
def expansion(x_exp: list, w_exp):
    """
    Expansion convolution through increasing channel dimension to provide higher-dimensional space for
    depthwise filter

    Args:
        x_exp (list): tensor of (Channel, Height, Width) 
        w_exp (tuple): weights for expansion (C_exp, C_in) 1x1 kernels
    """
    c_exp, c_in = w_exp.shape
    h, w = x_exp.shape[1], x_exp.shape[2]
    
    x_flat = x_exp.reshape(c_in, -1)
    out = w_exp @ x_flat
    return relu(out.reshape((c_exp, h, w)))

# Deptwhise convolution
def depthwise_conv():
    pass

# Squeeze-and-Excitation (SE)
def squeeze_excitation():
    pass

# Projection
def projection():
    pass
# Out:
#   Cell In[1], line 10
#     # Projection
#                    ^
# SyntaxError: incomplete input

# %%
# Batch Normalization

# %%
# Head Conv + Dropout + FC

# %%
# Convolution Neural Network Layers

def conv2d_forward():
    pass

def conv2d_backward():
    pass

def depthwise_conv2d_forward():
    pass

def depthwise_conv2d_backward():
    pass

def pointwise_conv2d_forward():
    pass

def pointwise_conv2d_backward():
    pass

def batch_norm2d_forward():
    pass

def batch_norm2d_backward():
    pass

def dropout_forward():
    pass

def dropout_backward():
    pass

def se_forward():
    pass

def se_backward():
    pass

def mbconv_forward():
    pass

def mbconv_backward():
    pass

def stemconv_forward():
    pass

def stemconv_backward():
    pass

def headconv_forward():
    pass

def headconv_backward():
    pass

def linear_forward():
    pass

def linear_backward():
    pass

def sigmoid_forward():
    pass

def sigmoid_backward():
    pass

def relu_forward():
    pass

def relu_backward():
    pass

def swish_forward():
    pass

def swish_backward():
    pass

def global_average_pooling_forward():
    pass

def global_average_pooling_backward():
    pass

def mse_loss_forward():
    pass

def mse_loss_backward():
    pass

def sgd_step():
    pass

def adam_step():
    pass

def update_weights():
    pass

def forward_pass():
    pass

def backward_pass():
    pass

def train_step():
    pass

def matmul():
    pass

def add_bias():
    pass

def reshape():
    pass

def transpose():
    pass

# %% [markdown]
# ## Mathematical Equation and Implementation

# %% [markdown]
# ### Core Math

# %% [markdown]
# ##### 1. Matrix Multiplication (`matmul`)
#
# Untuk:
# - $A \in \mathbb{R}^{m \times n}$
# - $B \in \mathbb{R}^{n \times p}$
#
# $$C = A \cdot B$$
#
# Dengan:
# $$C_{ij} = \sum_{k=1}^{n} A_{ik}B_{kj}$$
#
# Keluaran:
# - $C \in \mathbb{R}^{m \times p}$

# %%
def matmul(a: np.ndarray, b: np.ndarray) -> np.ndarray:
    return a @ p

# %% [markdown]
# ##### 2. Add Bias
# Untuk:
# - $X \in \mathbb{R}^{m \times n}$
# - $b \in \mathbb{R}$
#
# $$Y = X + b$$
#
# Dengan:
# $$Y_{ij} = X_{ij} + b_{ij}$$
#
# **Note**: bias ditambahkan per fitur

# %%
def add_bias(X: np.ndarray, b: np.ndarray) -> np.ndarray:
    return X + b

# %% [markdown]
# ##### 3. Reshape
# Reshaepe tidak mengubah value apapun, hanya memberikan index
#
# Untuk:
# - $X \in \mathbb{R}^{m \times n}$
# - $\text{reshape} \to Y \in \mathbb{R}^{p \times q}$
#
# Batasan:
# - Hanya berlaku jika dan hanya jika
# $$m \cdot n = p \cdot q$$
#
# Sehingga, diperoleh:
# $$Y_{ij} = X_{k}$$
# dengan
# $$k = i \cdot q + j$$

# %%
def reshape(X: np.ndarray, new_shape: tupele) -> np.ndarray:
    return np.reshape(X, new_shape)

# %% [markdown]
# ##### 4. Transpose
# Pertukaran axis: Kolom menjadi row dan sebaliknya
#
# Untuk:
# - $X \in \mathbb{R}^{m \times n}$
#
# $$X^{T} \in \mathbb{R}^{n \times m}$$
# dengan:
# $$\left( X^{T} \right) = X_{ji}$$

# %%
def transpose(X: np.ndarray, axes: tuple = None) -> np.ndarray:
    return np.transpose(X, axes=axes)

# %% [markdown]
# ### Activation Functions

# %% [markdown]
# ##### 1. Sigmoid

# %% [markdown]
# ###### **Forward**
# $$\sigma (x) = \frac{1}{1 + e^{-x}}$$

# %%
def sigmoid_forward(x: np.ndarray) -> np.ndarray:
    out = 1 / (1 + np.exp(-x))
    return out, out # Cache out untuk menghindari komputasi berulang pada sigmoid

# %% [markdown]
# ###### **Backward**
# $$\frac{\partial L}{\partial x} = \frac{\partial L}{\partial y}\cdot \sigma(x) \left(1 - \sigma(x)\right)$$

# %%
def sigmoid_backward(dout: np.ndarray, cache: np.ndarray) -> np.ndarray:
    # dout: gradien yang berasal dari layer di depan / setelahnya
    # cache: output sigmoid dari forward pass layer ini
    sig = cache
    return dout * sig * (1 - sig)

# %% [markdown]
# ##### 2. ReLU

# %% [markdown]
# ###### **Forward**
#
# $$\mathrm{ReLU} = \max(0, x)$$

# %%
def relu_forward(x: np.ndarray) -> np.ndarray:
    return np.maximum(0, x)

# %% [markdown]
# ###### **Backward**
#
# $$\frac{\partial L}{\partial x} = \frac{\partial L}{\partial y} \cdot \mathbf{1}_{x > 0}$$

# %%
def relu_backrward(dout: np.ndarray, cache: np.ndarray) -> np.ndarray:
    # dout: gradien yang berasal dari layer di depan / setelahnya
    # cache: output sigmoid dari forward pass layer ini
    relu = cache
    dx = dout * (x > 0)
    return dx

# %% [markdown]
# ##### 3. Swish (SiLU)

# %% [markdown]
# ###### **Forward**

# %% [markdown]
# ###### **Backward**

# %% [markdown]
# ### Loss Functions

# %% [markdown]
# ### Optimizer Functions

# %% [markdown]
# ### Linear / Fully-Connected Layer

# %% [markdown]
# ### Training Loop

# %% [markdown]
# ### Convolution Layer

# %% [markdown]
# ### Pooling Layer

# %% [markdown]
# ### Advanced Layers

# %% [markdown]
# ### SE Blocks

# %% [markdown]
# ### MBConv Blocks

# %% [markdown]
# ### Normalization & Regularization

# %% [markdown]
# ### Model Structure
